# %% [markdown]
# <a href="https://colab.research.google.com/github/Slkandu/py/blob/main/pyday3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Syntax
# df = pd.DataFrame(2D_numpy_array)

import numpy as np
import pandas as pd

n1 = np.array([[1,2],[3,4]])

df = pd.DataFrame(n1,columns= ["First Column", "Second Column"])

# %%
df= pd.read_excel("/content/Nfhs District Data.xlsx")

# %%
df.shape
# Out:
# (31, 6)

# %%
df.columns
# Out:
# Index(['KGISDist 1', 'Nfhs District Names',
#        'Children under 5 years who are stunted (height-for-age)18 (%)',
#        'Children under 5 years who are wasted (weight-for-height)18 (%)',
#        'Children under 5 years who are severely wasted (weight-for-height)19 (%)',
#        'Children under 5 years who are underweight (weight-for-age)18 (%)'],
#       dtype='object')

# %%
df.head()
# Out:
#    KGISDist 1 Nfhs District Names  \
# 0    Belagavi            Belgaum
# 1    Bagalkot           Bagalkot
# 2  Vijayapura            Bijapur
# 3       Bidar              Bidar
# 4     Raichur            Raichur
#
#    Children under 5 years who are stunted (height-for-age)18 (%)  \
# 0                                              32.78
# 1                                              48.26
# 2                                              45.94
# 3                                              36.82
# 4                                              39.79
#
#    Children under 5 years who are wasted (weight-for-height)18 (%)  \
# 0                                              23.57
# 1                                              16.85
# 2                                              14.96
# 3                                              22.09
# 4                                              23.23
#
#    Children under 5 years who are severely wasted (weight-for-height)19 (%)  \
# ...

# %%
df.tail()
# Out:
#            KGISDist 1 Nfhs District Names  \
# 26             Kolara              Kolar
# 27    Chikkaballapura    Chikkaballapura
# 28  Bengaluru (Rural)    Bangalore Rural
# 29         Ramanagara         Ramanagara
# 30       Vijayanagara        Vijayanagara
#
#     Children under 5 years who are stunted (height-for-age)18 (%)  \
# 26                                              31.09
# 27                                              31.32
# 28                                              36.57
# 29                                              15.62
# 30                                              36.08
#
#     Children under 5 years who are wasted (weight-for-height)18 (%)  \
# 26                                              15.53
# 27                                              16.12
# 28                                              16.24
# 29                                              20.01
# 30                                              22.89
#
# ...

# %%
df.dtypes
# Out:
# KGISDist 1                                                                   object
# Nfhs District Names                                                          object
# Children under 5 years who are stunted (height-for-age)18 (%)               float64
# Children under 5 years who are wasted (weight-for-height)18 (%)             float64
# Children under 5 years who are severely wasted (weight-for-height)19 (%)    float64
# Children under 5 years who are underweight (weight-for-age)18 (%)           float64
# dtype: object

# %%
# print column names

# Syntax
# df.columns

print(df.columns[2:5])
# Out:
# Index(['Children under 5 years who are stunted (height-for-age)18 (%)',
#        'Children under 5 years who are wasted (weight-for-height)18 (%)',
#        'Children under 5 years who are severely wasted (weight-for-height)19 (%)'],
#       dtype='object')

# %%
# Access Column Data using column name

# Syntax
# df['Column']

series_dis = df['KGISDist 1']

# %%
df.iloc[:,4]
# Out:
# 0     10.23
# 1      4.38
# 2      4.28
# 3     11.14
# 4     11.65
# 5      3.76
# 6      4.46
# 7      4.60
# 8     13.12
# 9      3.94
# 10    13.62
# 11     8.29
# 12     3.87
# 13    13.46
# 14     5.98
# 15    11.47
# 16     3.05
# 17    11.42
# 18     5.29
# 19     5.18
# 20    15.71
# 21     9.34
# 22     7.15
# 23     6.77
# 24    12.21
# 25     7.21
# 26     5.81
# 27     6.08
# 28     9.37
# 29     7.71
# 30    13.62
# Name: Children under 5 years who are severely wasted (weight-for-height)19 (%), dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 6 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   KGISDist 1                                                                31 non-null     object
#  1   Nfhs District Names                                                       31 non-null     object
#  2   Children under 5 years who are stunted (height-for-age)18 (%)             31 non-null     float64
#  3   Children under 5 years who are wasted (weight-for-height)18 (%)           31 non-null     float64
#  4   Children under 5 years who are severely wasted (weight-for-height)19 (%)  31 non-null     float64
#  5   Children under 5 years who are underweight (weight-for-age)18 (%)         31 non-null     float64
# dtypes: float64(4), object(2)
# memory usage: 1.6+ KB

# %%
df.columns
# Out:
# Index(['KGISDist 1', 'Nfhs District Names',
#        'Children under 5 years who are stunted (height-for-age)18 (%)',
#        'Children under 5 years who are wasted (weight-for-height)18 (%)',
#        'Children under 5 years who are severely wasted (weight-for-height)19 (%)',
#        'Children under 5 years who are underweight (weight-for-age)18 (%)'],
#       dtype='object')

# %%
#  Min, Max, Mean, Std, Median

# Syntax
# df['Column1'].min()

print("Minimum is:",
      df['Children under 5 years who are stunted (height-for-age)18 (%)'].min())

print("Maximum is: ",
      df['Children under 5 years who are stunted (height-for-age)18 (%)'].max())

print("Mean is: ",
      df['Children under 5 years who are stunted (height-for-age)18 (%)'].mean())

print("Standard deviation is: ",
      df['Children under 5 years who are stunted (height-for-age)18 (%)'].std())

print("Median is: ",
      df['Children under 5 years who are stunted (height-for-age)18 (%)'].median())
# Out:
# Minimum is: 15.62
# Maximum is:  57.6
# Mean is:  34.62322580645161
# Standard deviation is:  8.859549795596001
# Median is:  32.78

# %%
df.isnull().sum()
# Out:
# KGISDist 1                                                                  0
# Nfhs District Names                                                         0
# Children under 5 years who are stunted (height-for-age)18 (%)               0
# Children under 5 years who are wasted (weight-for-height)18 (%)             0
# Children under 5 years who are severely wasted (weight-for-height)19 (%)    0
# Children under 5 years who are underweight (weight-for-age)18 (%)           0
# dtype: int64
